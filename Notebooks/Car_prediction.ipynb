# %%
import numpy as np
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# To know the types of columns we can write
# df.dtypes
# To know the specific datatype column we can write
indexes = list(df.dtypes[df.dtypes == "object"].index)
indexes
# Out:
# ['Make',
#  'Model',
#  'Engine Fuel Type',
#  'Transmission Type',
#  'Driven_Wheels',
#  'Market Category',
#  'Vehicle Size',
#  'Vehicle Style']

# %%
for cols in df.columns:
    print(cols)
    print(df[cols].unique())
    print(df[cols].nunique())
    print()
# Out:
# Make
# ['BMW' 'Audi' 'FIAT' 'Mercedes-Benz' 'Chrysler' 'Nissan' 'Volvo' 'Mazda'
#  'Mitsubishi' 'Ferrari' 'Alfa Romeo' 'Toyota' 'McLaren' 'Maybach'
#  'Pontiac' 'Porsche' 'Saab' 'GMC' 'Hyundai' 'Plymouth' 'Honda'
#  'Oldsmobile' 'Suzuki' 'Ford' 'Cadillac' 'Kia' 'Bentley' 'Chevrolet'
#  'Dodge' 'Lamborghini' 'Lincoln' 'Subaru' 'Volkswagen' 'Spyker' 'Buick'
#  'Acura' 'Rolls-Royce' 'Maserati' 'Lexus' 'Aston Martin' 'Land Rover'
#  'Lotus' 'Infiniti' 'Scion' 'Genesis' 'HUMMER' 'Tesla' 'Bugatti']
# 48
#
# Model
# ['1 Series M' '1 Series' '100' '124 Spider' '190-Class' '2 Series' '200'
#  '200SX' '240SX' '240' '2' '3 Series Gran Turismo' '3 Series' '300-Class'
#  '3000GT' '300' '300M' '300ZX' '323' '350-Class' '350Z' '360' '370Z' '3'
#  '4 Series Gran Coupe' '4 Series' '400-Class' '420-Class' '456M'
#  '458 Italia' '4C' '4Runner' '5 Series Gran Turismo' '5 Series'
#  '500-Class' '500e' '500' '500L' '500X' '550' '560-Class' '570S' '575M'
# ...

# %%
for cols in df.columns:
    df.columns = df.columns.str.lower().str.replace(' ','_')
list(df.columns)
# Out:
# ['make',
#  'model',
#  'year',
#  'engine_fuel_type',
#  'engine_hp',
#  'engine_cylinders',
#  'transmission_type',
#  'driven_wheels',
#  'number_of_doors',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style',
#  'highway_mpg',
#  'city_mpg',
#  'popularity',
#  'msrp']

# %%
sns.histplot(df.msrp,bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# **Data Analysis**: The Above Graph tells us that , most of the Cars in our Dataset are not Expensive they are less than 1 million and a very few outliers means there are very few Luxury Cars in this Dataset
